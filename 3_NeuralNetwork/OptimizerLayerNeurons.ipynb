# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import warnings


warnings.filterwarnings('ignore')
# %matplotlib inline


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Neural Network with RMSE loss function

# %%
from helpers import load_data

DATA_TRAIN_PATH = "data/data_train.csv"
data = load_data(DATA_TRAIN_PATH)


DATA_TEST_PATH = "data/sampleSubmission.csv"
samples = load_data(DATA_TEST_PATH)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# take 15 more frequent users
g = data.groupby('user_id')['rating'].count()
top_users = g.sort_values(ascending=False)[:15]

# take 15 more frequent movies
g = data.groupby('movie_id')['rating'].count()
top_movies = g.sort_values(ascending=False)[:15]

# combine frequent users and most rated movies
top_r = data.join(top_users, rsuffix = '_r', how = 'inner', on = 'user_id')
top_r = top_r.join (top_movies, rsuffix = '_r', how = 'inner', on = 'movie_id')

pd.crosstab(top_r.user_id, top_r.movie_id, top_r.rating, aggfunc = np.sum)
# Out:
# movie_id  134   14  156  178  256   46  471  495  594  596    6   60  608  \
# user_id
# 1000      5.0  5.0  NaN  5.0  NaN  5.0  5.0  NaN  5.0  5.0  NaN  NaN  NaN
# 1570      5.0  NaN  NaN  NaN  NaN  NaN  NaN  5.0  NaN  5.0  5.0  5.0  NaN
# 1830      NaN  NaN  NaN  NaN  5.0  5.0  NaN  5.0  NaN  5.0  5.0  5.0  5.0
# 1878      5.0  5.0  NaN  5.0  5.0  5.0  5.0  NaN  NaN  NaN  NaN  NaN  NaN
# 2038      5.0  5.0  NaN  NaN  NaN  NaN  NaN  NaN  5.0  NaN  5.0  5.0  NaN
# 4600      5.0  NaN  5.0  5.0  5.0  NaN  5.0  5.0  NaN  5.0  NaN  NaN  NaN
# 5289      5.0  NaN  5.0  5.0  5.0  5.0  5.0  NaN  5.0  NaN  5.0  5.0  5.0
# 5512      NaN  5.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0  NaN  NaN  5.0
# 7014      5.0  5.0  5.0  NaN  NaN  5.0  NaN  5.0  NaN  NaN  NaN  5.0  NaN
# 8575      5.0  NaN  5.0  NaN  NaN  5.0  5.0  5.0  5.0  NaN  5.0  5.0  5.0
# 8706      5.0  5.0  NaN  5.0  5.0  NaN  NaN  NaN  NaN  5.0  5.0  5.0  5.0
# 9377      NaN  5.0  NaN  NaN  NaN  NaN  5.0  NaN  5.0  5.0  5.0  5.0  5.0
# 966       NaN  5.0  NaN  5.0  5.0  NaN  5.0  5.0  5.0  NaN  5.0  NaN  NaN
# 9711      5.0  5.0  5.0  5.0  NaN  5.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9827      NaN  NaN  NaN  5.0  NaN  NaN  NaN  NaN  5.0  5.0  5.0  5.0  5.0
#
# movie_id  668  978
# user_id
# 1000      5.0  3.0
# 1570      NaN  5.0
# 1830      NaN  NaN
# 1878      5.0  NaN
# 2038      5.0  NaN
# 4600      NaN  5.0
# 5289      5.0  NaN
# 5512      NaN  5.0
# 7014      NaN  NaN
# 8575      NaN  5.0
# 8706      NaN  5.0
# 9377      NaN  NaN
# 966       5.0  5.0
# 9711      5.0  NaN
# 9827      5.0  NaN

# %%
user_enc = LabelEncoder()
data ['user'] = user_enc.fit_transform(data['user_id'].values)
samples ['user'] = user_enc.fit_transform(samples['user_id'].values)
n_users = data ['user'].nunique()

item_enc = LabelEncoder()
data ['movie'] = item_enc.fit_transform(data['movie_id'].values)
samples['movie'] = item_enc.fit_transform(samples['movie_id'].values)
n_movies = data ['movie'].nunique()


data ['rating'] = data ['rating'].values.astype(np.int)
n_factors = 50

# %%
from keras.utils import np_utils

X = data[['user', 'movie']].values
y = data ['rating']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=42)

X_train_array = [X_train[:,0], X_train[:,1]]
X_test_array = [X_test[:,0], X_test[:,1]]
encoder = LabelEncoder()
encoder.fit(y_train)
encoder_train = encoder.transform(y_train)
encoder_test = encoder.transform(y_test)

y_train = np_utils.to_categorical(encoder_train)
y_test = np_utils.to_categorical(encoder_test)
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Model,load_model
from keras.layers import Input, Reshape, Dot
from keras.layers.embeddings import Embedding
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.layers import Concatenate, Dense, Dropout, Add, Activation, Lambda
from keras.callbacks import EarlyStopping
usualCallback = EarlyStopping()

# %%
from OptimizerLayerNeurons import optimizerLayerNeuron

nb_max_layers = 10
nb_max_neurons = 20
model = optimizerLayerNeuron(nb_max_layers,nb_max_neurons,n_users, n_movies, n_factors, X, y)

if os.path.exists('model_optimizerLayerNeuron.h5'):
    model = load_model('model_optimizerLayerNeuron.h5')
else:
    history_dummy = model.fit(x=X_train_array, y= y_train, batch_size=1024, epochs=10000, verbose=1, validation_data=(X_test_array,y_test), callbacks=[usualCallback])
    model.save('model_optimizerLayerNeuron.h5')
    plt.plot(history_dummy.history['val_loss'])
    plt.xlabel("Epochs")
    plt.ylabel("Test Error")
# Out:
# WARNING:tensorflow:From /home/emma-hoggett/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1059256 samples, validate on 117696 samples
# Epoch 1/10000
# 1059256/1059256 [==============================] - 14s 13us/step - loss: 0.1355 - val_loss: 0.1323
# Epoch 2/10000
# 1059256/1059256 [==============================] - 15s 14us/step - loss: 0.1316 - val_loss: 0.1322
# Epoch 3/10000
# 1059256/1059256 [==============================] - 14s 14us/step - loss: 0.1313 - val_loss: 0.1322
# Train on 1059256 samples, validate on 117696 samples
# Epoch 1/10000
#  385024/1059256 [=========>....................] - ETA: 10s - loss: 0.1383
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1e561be2d9a7> in <module>
#       3 nb_max_layers = 10
#       4 nb_max_neurons = 20
# ----> 5 model = optimizerLayerNeuron(nb_max_layers,nb_max_neurons,n_users, n_movies, n_factors, X, y)
#       6
#       7 if os.path.exists('model_optimizerLayerNeuron.h5'):
#
# ~/git_workspace/Project2_ML/3_NeuralNetwork/OptimizerLayerNeurons.py in optimizerLayerNeuron(nb_max_layers, nb_max_neurons, n_users, n_movies, n_factors, X, y)
#      76
#      77             history = model_temp.fit(x=X_train_array, y=y_train,  batch_size=1024,
# ---> 78                              epochs=10000,verbose=1,validation_data=(X_test_array, y_test),callbacks=[usualCallback])
#      79             new_layer_mse.append(history.history['val_loss'][-1])
#      80
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3295         self._outputs_structure,
#    3296         fetched[:len(self.outputs)],
# -> 3297         expand_composites=True)
#    3298     # We need to evaluate any composite tensor objects that have been
#    3299     # reconstructed in 'pack_sequence_as', since otherwise they'll be output as
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/nest.py in pack_sequence_as(structure, flat_sequence, expand_composites)
#     448           "flat_sequence had %d elements.  Structure: %s, flat_sequence: %s." %
#     449           (len(flat_structure), len(flat_sequence), structure, flat_sequence))
# --> 450   return _sequence_like(structure, packed)
#     451
#     452
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/nest.py in _sequence_like(instance, args)
#     132     result = dict(zip(_sorted(instance), args))
#     133     return type(instance)((key, result[key]) for key in instance)
# --> 134   elif _is_namedtuple(instance) or _is_attrs(instance):
#     135     return type(instance)(*args)
#     136   elif _is_composite_tensor(instance):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in IsAttrs(o)
#    2514
#    2515     """
# -> 2516     return _pywrap_tensorflow_internal.IsAttrs(o)
#    2517
#    2518 def IsTensor(o):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Optimize Layers, Neurons, Dropouts & Models

# %%
X_samples = samples[['user', 'movie']].values
X_samples_array = [X_samples[:,0], X_samples[:,1]]

# %%
sample_pred = model.predict(X_samples_array)

# %%
rating_samples = (np.argmax(sample_pred,1)+1).tolist()

DATA_TEST_PATH = "data/sampleSubmission.csv"
samples = load_data(DATA_TEST_PATH)

samples['rating'] = rating_samples

# %%
from helpers import create_csv
PATH_SUBMISSION = "DummyNeuralNetworkPrediction.csv"
create_csv(PATH_SUBMISSION, samples)

# %%
X=np.random.randint(1000, size=(32, 10))

X.shape
# Out:
# (32, 10)
